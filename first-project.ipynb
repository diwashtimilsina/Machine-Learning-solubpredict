# %% [markdown]
# **My first ML Project**

# %%
#importing all required libraries
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression 
from sklearn.metrics import mean_squared_error , r2_score
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler

# %%
df = pd.read_csv('delaney.csv')
df.head()
# Out:
#    MolLogP    MolWt  NumRotatableBonds  AromaticProportion  logS
# 0   2.5954  167.850                0.0                 0.0 -2.18
# 1   2.3765  133.405                0.0                 0.0 -2.00
# 2   2.5938  167.850                1.0                 0.0 -1.74
# 3   2.0289  133.405                1.0                 0.0 -1.48
# 4   2.9189  187.375                1.0                 0.0 -3.04

# %% [markdown]
# ***It is dataset of finding solubility or chemistry model to predict weather the chemical will be soluble or insoluble.***

# %%
df
# Out:
#       MolLogP    MolWt  NumRotatableBonds  AromaticProportion   logS
# 0     2.59540  167.850                0.0            0.000000 -2.180
# 1     2.37650  133.405                0.0            0.000000 -2.000
# 2     2.59380  167.850                1.0            0.000000 -1.740
# 3     2.02890  133.405                1.0            0.000000 -1.480
# 4     2.91890  187.375                1.0            0.000000 -3.040
# ...       ...      ...                ...                 ...    ...
# 1139  1.98820  287.343                8.0            0.000000  1.144
# 1140  3.42130  286.114                2.0            0.333333 -4.925
# 1141  3.60960  308.333                4.0            0.695652 -3.893
# 1142  2.56214  354.815                3.0            0.521739 -3.790
# 1143  2.02164  179.219                1.0            0.461538 -2.581
#
# [1144 rows x 5 columns]

# %%
#data preprocessing and cleaning the data
#seperating data as x and y
y = df['logS']
x = df.drop('logS',axis=1)#if axis = 1 it drop column else or 0 : drops row
x.head()
# Out:
#    MolLogP    MolWt  NumRotatableBonds  AromaticProportion
# 0   2.5954  167.850                0.0                 0.0
# 1   2.3765  133.405                0.0                 0.0
# 2   2.5938  167.850                1.0                 0.0
# 3   2.0289  133.405                1.0                 0.0
# 4   2.9189  187.375                1.0                 0.0

# %%
#since we got both x and y
#splitting data
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2,random_state=100)
#randomness for training and testing data

# %%
x_train
# Out:
#      MolLogP    MolWt  NumRotatableBonds  AromaticProportion
# 107  3.14280  112.216                5.0            0.000000
# 378 -2.07850  142.070                0.0            0.000000
# 529 -0.47730  168.152                0.0            0.000000
# 546 -0.86740  154.125                0.0            0.000000
# 320  1.62150  100.161                2.0            0.000000
# ..       ...      ...                ...                 ...
# 802  3.00254  250.301                1.0            0.842105
# 53   2.13860   82.146                3.0            0.000000
# 350  5.76304  256.348                0.0            0.900000
# 79   3.89960  186.339               10.0            0.000000
# 792  2.52334  310.297                3.0            0.300000
#
# [915 rows x 4 columns]

# %%
y_train
# Out:
# 107   -4.440
# 378   -1.250
# 529   -1.655
# 546   -1.886
# 320   -0.740
#        ...
# 802   -2.925
# 53    -2.680
# 350   -7.020
# 79    -4.800
# 792   -3.240
# Name: logS, Length: 915, dtype: float64

# %%
x_test
# Out:
#       MolLogP    MolWt  NumRotatableBonds  AromaticProportion
# 822   2.91000  172.268                7.0            0.000000
# 118   7.27400  360.882                1.0            0.666667
# 347   1.94040  145.161                0.0            0.909091
# 1123  1.98640  119.378                0.0            0.000000
# 924   1.70062  108.140                0.0            0.750000
# ...       ...      ...                ...                 ...
# 1114  1.76210  478.513                4.0            0.000000
# 427   6.32820  276.338                0.0            1.000000
# 711   0.04430  218.205                5.0            0.000000
# 4     2.91890  187.375                1.0            0.000000
# 948   3.56010  318.328                2.0            0.750000
#
# [229 rows x 4 columns]

# %%
y_test
# Out:
# 822    -3.380
# 118    -8.010
# 347    -2.160
# 1123   -1.170
# 924    -0.730
#         ...
# 1114   -4.130
# 427    -9.018
# 711    -0.600
# 4      -3.040
# 948    -2.900
# Name: logS, Length: 229, dtype: float64

# %% [markdown]
# **Model Building**
# ** **
# **Linear Regression**

# %%
#training the model
lr = LinearRegression()
lr.fit(x_train, y_train)
# Out:
# LinearRegression()

# %% [markdown]
# **Applying model to make a Prediction**

# %%
y_lr_train_pred = lr.predict(x_train)
y_lr_test_pred = lr.predict(x_test)
#print(y_lr_test_pred,y_lr_train_preda
Data =  np.array(['y_lr_train_pred','y_lr_test_pred'])

# %%
#Normalizing the data given|
max_y_test = np.max(y_test)
min_y_test =np.min(y_test)
max_y_train =np.max(y_train)
min_y_train =np.min(y_train)

normalized_y_train =(y_train- min_y_train)/(max_y_train-min_y_train)
normalized_y_test =(y_test- min_y_test)/(max_y_test-min_y_test)

#normalizing predicted data
min_y_lr_train_pred = np.min(y_lr_train_pred)
min_y_lr_test_pred = np.min(y_lr_test_pred)
max_y_lr_train_pred = np.max(y_lr_train_pred)
max_y_lr_test_pred = np.max(y_lr_test_pred)
normalized_y_train_pred = (y_lr_train_pred- min_y_lr_train_pred)/(max_y_lr_train_pred- min_y_lr_train_pred)
normalized_y_test_pred = (y_lr_test_pred- min_y_lr_test_pred)/(max_y_lr_test_pred- min_y_lr_test_pred)

# %%
#printing normalized data
normalized_y_test.info()
normalized_y_test_pred
# Out:
# <class 'pandas.core.series.Series'>
# Index: 229 entries, 822 to 948
# Series name: logS
# Non-Null Count  Dtype
# --------------  -----
# 229 non-null    float64
# dtypes: float64(1)
# memory usage: 3.6 KB
# array([0.59719956, 0.22064982, 0.63764631, 0.68031605, 0.67644543,
#        0.76132435, 0.79363542, 0.79690405, 0.38463839, 0.52677834,
#        0.52558976, 0.65781108, 0.72222812, 0.72222124, 0.47053943,
#        0.68919215, 0.72016539, 0.58866312, 0.5452386 , 0.39588176,
#        0.58179212, 0.43885263, 0.38703624, 0.67009291, 0.4935294 ,
#        0.43906825, 0.59348183, 0.48986202, 0.50502625, 0.88545597,
#        0.72497424, 0.4892714 , 0.63393546, 0.71875354, 0.79673464,
#        0.70776524, 0.61918266, 0.58948395, 0.42062727, 0.70121666,
#        0.71874202, 0.68052975, 0.31655083, 0.2113592 , 0.38125933,
#        0.5088983 , 0.56691066, 0.95579707, 0.84016625, 0.65399437,
#        0.6923158 , 0.43906825, 0.90933641, 0.5876623 , 0.43683531,
# ...

# %% [markdown]
# **Evaluation of Model Prediction**

# %%
lr_train_mse = mean_squared_error(normalized_y_train, normalized_y_train_pred)
lr_train_r2 = r2_score(normalized_y_train,normalized_y_train_pred)

lr_test_mse = mean_squared_error(normalized_y_test, normalized_y_test_pred)
lr_test_r2 = r2_score(normalized_y_test,normalized_y_test_pred)

# %%
print('lr_train_mse :', lr_train_mse)
print('lr_test_mse :', lr_test_mse)
print('lr_train_r2 :', lr_train_r2)
print('lr_test_r2 :', lr_test_r2)
# Out:
# lr_train_mse : 0.00952874597907545
# lr_test_mse : 0.01279534323982288
# lr_train_r2 : 0.7348051245803697
# lr_test_r2 : 0.5723586489167003

# %% [markdown]
# Let's break down the results:
#
# MSE (Mean Squared Error):
#
# Train MSE: 0.0095
# Test MSE: 0.0128
# Lower MSE values are generally better as they indicate that the model's predictions are closer to the actual values. The fact that the training MSE is slightly lower than the test MSE suggests that your model is performing well on the training data and reasonably well on unseen data.
# R² (Coefficient of Determination):
#
# Train R²: 0.7348
# Test R²: 0.5724
# R² values range from 0 to 1, with 1 indicating a perfect fit. A training R² of 0.7348 indicates that about 73.48% of the variance in the training data is explained by the model. The test R² of 0.5724 means that 57.24% of the variance in the test data is explained by the model.

# %%
lr_results = pd.DataFrame(['Linear Regression',[lr_train_mse],lr_test_mse,lr_test_r2,lr_train_r2]).transpose()
lr_results.columns = ['Method','Training MSE','Testing MSE','Testing r2','Training r2']
print(lr_results)
# Out:
#               Method           Training MSE Testing MSE Testing r2 Training r2
# 0  Linear Regression  [0.00952874597907545]    0.012795   0.572359    0.734805

# %%
print(lr_results)
# Out:
#               Method           Training MSE Testing MSE Testing r2 Training r2
# 0  Linear Regression  [0.00952874597907545]    0.012795   0.572359    0.734805

# %% [markdown]
# **Data Visualization of Predicted model**

# %%
plt.scatter(x=normalized_y_train,y=normalized_y_train_pred,alpha=1)
plt.Figure(figsize=(30,30))
plt.xlim(-0.2,1.2)
plt.ylim(-0.2,1.2)
plt.ylabel('Predicted Logs')
plt.xlabel('Experimented LogS')

#for line
z = np.polyfit(normalized_y_train,normalized_y_train_pred ,1)
p = np.poly1d(z)
color = '#FB9099'
plt.plot(y_train , p(y_train),color)

# %% [markdown]
# **FUnction to check solubility**

# %%
#user input
# User input
MolLogP = float(input("Enter MolLogP: "))
MolWt = float(input("Enter MolWt: "))
NumRotatableBonds = float(input("Enter NumRotatableBonds: "))
AromaticProportion = float(input("Enter AromaticProportion: "))

# Predict solubility
user_input = pd.DataFrame([[MolLogP, MolWt, NumRotatableBonds, AromaticProportion]],
                          columns=['MolLogP', 'MolWt', 'NumRotatableBonds', 'AromaticProportion'])

# %%
scaler = MinMaxScaler()
scaler.fit(x_train,y_train)
new_user_input = pd.DataFrame([[scaler.transform(user_input)]])
new_user_input.head()
# Out:
#                                                    0
# 0  [[0.4772494432071269, -0.033166823638813056, 0...

# %%
predicted_logS = lr.predict(user_input)
print(predicted_logS)
# Out:
# [-0.96841178]

# %%
if predicted_logS >0.5 :
    print("the molecule is soluble")

else :
    print("the model is not soluble")
# Out:
# the model is not soluble
